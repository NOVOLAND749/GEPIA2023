# %%
import matplotlib.pyplot as plt

from database import DatabaseAPI
import numpy as np
import pandas as pd

# %%
api = DatabaseAPI(db_name='dataset',collection_name='test')

# %%
api.db.list_collection_names()
# Out:
# ['TCGA-TGCT-tumor',
#  'TCGA-BLCA-tumor',
#  'TCGA-UCEC-normal',
#  'TCGA-STAD-tumor',
#  'TCGA-STAD-normal',
#  'TCGA-COAD-tumor',
#  'TCGA-CESC-normal',
#  'TCGA-ESCA-normal',
#  'TCGA-KIRC-normal',
#  'TCGA-ACC-tumor',
#  'TCGA-THYM-tumor',
#  'TCGA-OV-tumor',
#  'TCGA-LAML-tumor',
#  'TCGA-KIRP-tumor',
#  'TCGA-HNSC-tumor',
#  'TCGA-PAAD-tumor',
#  'TCGA-SARC-normal',
#  'TCGA-SARC-tumor',
#  'TCGA-PRAD-tumor',
#  'TCGA-MESO-tumor',
#  'TCGA-DLBC-tumor',
#  'TCGA-COAD-normal',
#  'TCGA-READ-tumor',
#  'TCGA-LUAD-tumor',
#  'TCGA-CHOL-normal',
#  'TCGA-THCA-tumor',
#  'TCGA-UVM-tumor',
#  'TCGA-LIHC-normal',
#  'TCGA-KICH-normal',
#  'TCGA-KICH-tumor',
#  'TCGA-THCA-normal',
#  'TCGA-UCS-tumor',
#  'TCGA-BLCA-normal',
#  'TCGA-ESCA-tumor',
#  'TCGA-PAAD-normal',
#  'TCGA-PCPG-normal',
#  'TCGA-UCEC-tumor',
#  'TCGA-PCPG-tumor',
#  'TCGA-BRCA-normal',
#  'TCGA-LGG-tumor',
#  'TCGA-GBM-normal',
#  'TCGA-GBM-tumor',
#  'TCGA-LUAD-normal',
#  'TCGA-LIHC-tumor',
#  'TCGA-KIRC-tumor',
#  'TCGA-CHOL-tumor',
#  'TCGA-SKCM-normal',
#  'TCGA-CESC-tumor',
#  'TCGA-READ-normal',
#  'TCGA-BRCA-tumor',
#  'TCGA-SKCM-tumor',
#  'TCGA-KIRP-normal',
#  'TCGA-LUSC-normal',
#  'TCGA-THYM-normal',
#  'TCGA-PRAD-normal',
#  'TCGA-LUSC-tumor',
#  'TCGA-HNSC-normal']

# %%
a = api.read_metadata(key="ERBB2",metadata_name="TCGA-SARC-tumor")

# %%
b = api.read_metadata(key="ERBB2",metadata_name="TCGA-SARC-normal")

# %%
api.db.list_collection_names()
# Out:
# ['TCGA-TGCT-tumor',
#  'TCGA-BLCA-tumor',
#  'TCGA-UCEC-normal',
#  'TCGA-STAD-tumor',
#  'TCGA-STAD-normal',
#  'TCGA-COAD-tumor',
#  'TCGA-CESC-normal',
#  'TCGA-ESCA-normal',
#  'TCGA-KIRC-normal',
#  'TCGA-ACC-tumor',
#  'TCGA-THYM-tumor',
#  'TCGA-OV-tumor',
#  'TCGA-LAML-tumor',
#  'TCGA-KIRP-tumor',
#  'TCGA-HNSC-tumor',
#  'TCGA-PAAD-tumor',
#  'TCGA-SARC-normal',
#  'TCGA-SARC-tumor',
#  'TCGA-PRAD-tumor',
#  'TCGA-MESO-tumor',
#  'TCGA-DLBC-tumor',
#  'TCGA-COAD-normal',
#  'TCGA-READ-tumor',
#  'TCGA-LUAD-tumor',
#  'TCGA-CHOL-normal',
#  'TCGA-THCA-tumor',
#  'TCGA-UVM-tumor',
#  'TCGA-LIHC-normal',
#  'TCGA-KICH-normal',
#  'TCGA-KICH-tumor',
#  'TCGA-THCA-normal',
#  'TCGA-UCS-tumor',
#  'TCGA-BLCA-normal',
#  'TCGA-ESCA-tumor',
#  'TCGA-PAAD-normal',
#  'TCGA-PCPG-normal',
#  'TCGA-UCEC-tumor',
#  'TCGA-PCPG-tumor',
#  'TCGA-BRCA-normal',
#  'TCGA-LGG-tumor',
#  'TCGA-GBM-normal',
#  'TCGA-GBM-tumor',
#  'TCGA-LUAD-normal',
#  'TCGA-LIHC-tumor',
#  'TCGA-KIRC-tumor',
#  'TCGA-CHOL-tumor',
#  'TCGA-SKCM-normal',
#  'TCGA-CESC-tumor',
#  'TCGA-READ-normal',
#  'TCGA-BRCA-tumor',
#  'TCGA-SKCM-tumor',
#  'TCGA-KIRP-normal',
#  'TCGA-LUSC-normal',
#  'TCGA-THYM-normal',
#  'TCGA-PRAD-normal',
#  'TCGA-LUSC-tumor',
#  'TCGA-HNSC-normal']

# %%
Disease = []
Type = []
count = []

# %%
count += a
count += b

# %%
len(count)
# Out:
# 1482

# %%
Disease += ['SARC']*(len(a)+len(b))
Type += ['Tumor']*len(a) + ['Normal']*len(b)

# %%
df = pd.DataFrame({'Disease':Disease,'Type':Type,'count':count})

# %%
df
# Out:
#      Disease    Type      count
# 0       BRCA   Tumor  13.829425
# 1       BRCA   Tumor  13.166948
# 2       BRCA   Tumor  14.488782
# 3       BRCA   Tumor  15.229908
# 4       BRCA   Tumor  13.585784
# ...      ...     ...        ...
# 1477    SARC   Tumor  10.619303
# 1478    SARC   Tumor   7.339850
# 1479    SARC   Tumor  12.577193
# 1480    SARC  Normal  14.054520
# 1481    SARC  Normal  11.584963
#
# [1482 rows x 3 columns]

# %%
from plotting import boxplot
boxplot(df,x='Disease',y='count',hue='Type',box_pairs=[(('SARC','Tumor'),('SARC','Normal'))])
plt.ylabel('Log2(Count+1)')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# SARC_Tumor v.s. SARC_Normal: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.451e-01 U_stat=1.370e+02
# Text(91.97222222222221, 0.5, 'Log2(Count+1)')

# %%
import matplotlib.pyplot as plt

# %%
"SARC".split('&')
# Out:
# ['SARC']
